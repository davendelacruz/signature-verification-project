# %%
import time
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve,roc_auc_score

from tensorflow import keras
from keras_tuner.tuners import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D,ZeroPadding2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import pickle
# Out:
# C:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def save_pickle(variable,filename,folder):
    pickle_out=open(str(folder)+"/"+str(filename) + ".pickle","wb")
    pickle.dump(variable,pickle_out)
    pickle_out.close()
    
def load_pickle(filename,folder):
    return pickle.load(open(str(folder)+"/"+str(filename) + ".pickle","rb"))

# %%
def network_analysis(network_model,model_fit,X_test,y_test):
    test_loss, test_acc = network_model.evaluate(X_test, y_test)
    y_preds=pd.DataFrame(network_model.predict(X_test))
    fpr, tpr, _=roc_curve(y_test,y_preds)
    far,frr=fpr,1-tpr
    err=max(np.argwhere(np.diff(np.sign(far - frr))).flatten())
    x_points=np.linspace(0,1,num=len(far))
    
    print('Test accuracy:' + str(round(test_acc*100,2))+"%")
    print('Model fit and testing time:' + str(round(end - start,2))+"s")
    
    figure, axis = plt.subplots(2,2,figsize=(15,15))
    
    axis[0,0].plot(model_fit.history['loss'],'k',linewidth=3.0)
    axis[0,0].plot(model_fit.history['val_loss'],'b',linewidth=3.0)
    axis[0,0].legend(['Training loss', 'Validation Loss'],fontsize=12)
    axis[0,0].set_xlabel('Epochs ',fontsize=16)
    axis[0,0].set_ylabel('Loss',fontsize=16)
    axis[0,0].set_title('Loss Curves',fontsize=16)
    
    axis[0,1].plot(model_fit.history['accuracy'],'k',linewidth=3.0)
    axis[0,1].plot(model_fit.history['val_accuracy'],'b',linewidth=3.0)
    axis[0,1].legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
    axis[0,1].set_xlabel('Epochs ',fontsize=16)
    axis[0,1].set_ylabel('Accuracy',fontsize=16)
    axis[0,1].set_title('Accuracy Curves',fontsize=16)
    
    axis[1,0].set_title("ROC Curve",fontsize=16)
    axis[1,0].plot(fpr,tpr,'b')
    axis[1,0].set_ylabel('TPR: True Positive Rate')
    axis[1,0].set_ylim(0, 1)
    axis[1,0].set_xlabel('FPR: False Positive Rate')
    axis[1,0].set_xlim(0, 1)
    
    axis[1,1].set_title("FRR FAR Curve",fontsize=16)
    axis[1,1].plot(x_points,far,'k',label ='FAR')
    axis[1,1].plot(x_points,frr,'b',label ='FRR')
    axis[1,1].scatter(x_points[err], far[err],s=100)
    axis[1,1].text(x_points[err]+0.05,far[err],"Equal Error Rate ~" +
               str(round(far[err],4)),fontsize = 10)
    axis[1,1].legend(loc ="center left")
    axis[1,1].set_ylabel('Error Rate')
    axis[1,1].set_ylim(0, 1)
    axis[1,1].axes.get_xaxis().set_visible(False)
    

    plt.show()

# %%
def build_cnn_model(hp):
    CNN_model = Sequential()
    
    CNN_model.add(Conv2D(hp.Int("input_layer",32,256,32),
                         3,padding='same', activation="relu",
                         input_shape=X[1,:].shape, name="Input_Layer"))
    CNN_model.add(MaxPooling2D(pool_size=(2, 2)))
    CNN_model.add(BatchNormalization())
    CNN_model.add(Dropout(0.8))
    
    for i in range(3):
        CNN_model.add(Conv2D(hp.Int(f'conv_{i}_layers',32,512,32),3,
                             padding='same', activation="relu",name=f"Convolutional_Layer_{i}"))
        CNN_model.add(BatchNormalization())
        CNN_model.add(MaxPooling2D(pool_size=(2, 2)))
        
    CNN_model.add(Flatten())
    CNN_model.add(Dense(32,activation="relu",name='FullyConnected_Layer'))
    CNN_model.add(Dropout(0.6))
    
    CNN_model.add(Dense(1, activation='sigmoid', name='Output_Layer'))
    
    opt=Adam(learning_rate=1e-4)
    CNN_model.compile(optimizer=opt, 
                      loss="binary_crossentropy",
                      metrics=['accuracy'])
    
    return CNN_model

# %%
def best_network_hyperparameter(model_builder,trials,filename):
    tuner = RandomSearch(
        model_builder,
        objective='val_accuracy',
        max_trials=trials,
        executions_per_trial=1,
        directory='project',
        project_name=filename)
    criterion=EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
    tuner_result = tuner.search(X_train, y_train,epochs=20,batch_size=64,validation_split=0.1,callbacks=[criterion])
    
    return tuner.get_best_hyperparameters()[0]

# %%
def network_fit(network_model,bsize,epoch,X_train,y_train):
    criterion=EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=70)
    model_fit = network_model.fit(X_train, y_train, batch_size=bsize, epochs=epoch, verbose=2,
                      validation_split=0.1,callbacks=[criterion])
    return model_fit

# %%
#loading data
random_state=42
X_data_file,y_data_file,data_folder="X","y","data"
X_data=load_pickle(X_data_file,data_folder)
y_data=load_pickle(y_data_file,data_folder)

# %%
X=np.asarray(X_data).astype('float64')/255
y=np.array(y_data)
Xnn=np.asarray(X_data).astype('float64')/255
ynn=np.array(y_data)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.3, 
                                                    stratify=y,
                                                    shuffle=True,
                                                    random_state=42)

# %%
filename,folder="cnn_hyperparameter","project"
#cnn_hyperparameter=best_network_hyperparameter(build_cnn_model,100,filename)
#save_pickle(cnn_hyperparameter,filename,folder)

# %%
cnn_hyperparameters=load_pickle(filename,folder)
print(cnn_hyperparameters.values)
# Out:
# {'input_layer': 224, 'conv_0_layers': 48, 'conv_1_layers': 80, 'conv_2_layers': 80}

# %%
CNN_model=build_cnn_model(cnn_hyperparameters)
CNN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (Conv2D)        (None, 96, 96, 224)       2240
#
#  max_pooling2d (MaxPooling2D  (None, 48, 48, 224)      0
#  )
#
#  batch_normalization (BatchN  (None, 48, 48, 224)      896
#  ormalization)
#
#  dropout (Dropout)           (None, 48, 48, 224)       0
#
#  Convolutional_Layer_0 (Conv  (None, 48, 48, 48)       96816
#  2D)
#
#  batch_normalization_1 (Batc  (None, 48, 48, 48)       192
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 24, 24, 48)       0
#  2D)
#
#  Convolutional_Layer_1 (Conv  (None, 24, 24, 80)       34640
#  2D)
#
#  batch_normalization_2 (Batc  (None, 24, 24, 80)       320
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 80)       0
#  2D)
#
#  Convolutional_Layer_2 (Conv  (None, 12, 12, 80)       57680
#  2D)
#
#  batch_normalization_3 (Batc  (None, 12, 12, 80)       320
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 80)         0
#  2D)
#
#  flatten (Flatten)           (None, 2880)              0
#
#  FullyConnected_Layer (Dense  (None, 32)               92192
#  )
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  Output_Layer (Dense)        (None, 1)                 33
#
# =================================================================
# Total params: 285,329
# Trainable params: 284,465
# Non-trainable params: 864
# _________________________________________________________________

# %%
start = time.time()
CNN_fit=network_fit(CNN_model,16,120,X_train,y_train)
end = time.time()
# Out:
# Epoch 1/120
# 43/43 - 6s - loss: 1.2280 - accuracy: 0.5255 - val_loss: 0.7193 - val_accuracy: 0.4026 - 6s/epoch - 143ms/step
# Epoch 2/120
# 43/43 - 1s - loss: 0.7149 - accuracy: 0.6201 - val_loss: 0.7530 - val_accuracy: 0.4026 - 1s/epoch - 25ms/step
# Epoch
- val_accuracy: 0.6883 - 1s/epoch - 25ms/step
# Epoch 25/120
# 43/43 - 1s - loss: 0.3679 - accuracy: 0.8195 - val_loss: 0.5424 - val_accuracy: 0.7273 - 1s/epoch - 25ms/step
# Epoch 26/120
# 43/43 - 1s - loss: 0.3743 - accuracy: 0.8122 - val_loss: 0.5241 - val_accuracy: 0.7143 - 1s/epoch - 25ms/step
# Epoch 27/120
# 43/43 - 1s - loss: 0.3551 - accuracy: 0.8282 - val_loss: 0.5202 - val_accuracy: 0.7143 - 1s/epoch - 25ms/step
# Epoch 28/120
# 43/43 - 1s - loss: 0.3536 - accuracy: 0.8297 - val_loss: 0.5408 - val_accuracy: 0.7403 - 1s/epoch - 25ms/step
# Epoch 29/120
# 43/43 - 1s - loss: 0.3370 - accuracy: 0.8501 - val_loss: 0.5683 - val_accuracy: 0.6883 - 1s/epoch - 25ms/step
# Epoch 30/120
# 43/43 - 1s - loss: 0.3302 - accuracy: 0.8370 - val_loss: 0.6363 - val_accuracy: 0.6753 - 1s/epoch - 25ms/step
# Epoch 31/120
# 43/43 - 1s - loss: 0.3122 - accuracy: 0.8515 - val_loss: 0.5817 - val_accuracy: 0.6494 - 1s/epoch - 25ms/step
# Epoch 32/120
# 43/43 - 1s - loss: 0.3145 - accuracy: 0.8617 - val_loss: 0.5866 - val_accuracy: 0.6494 - 1s/epoch - 25ms/step
# Epoch 33/120
# 43/43 - 1s - loss: 0.3209 - accuracy: 0.8486 - val_loss: 0.6483 - val_accuracy: 0.6364 - 1s/epoch - 25ms/step
# Epoch 34/120
# 43/43 - 1s - loss: 0.2870 - accuracy: 0.8544 - val_loss: 0.5672 - val_accuracy: 0.6753 - 1s/epoch - 25ms/step
# Epoch 35/120
# 43/43 - 1s - loss: 0.3029 - accuracy: 0.8544 - val_loss: 0.6359 - val_accuracy: 0.5974 - 1s/epoch - 25ms/step
# Epoch 36/120
# 43/43 - 1s - loss: 0.2451 - accuracy: 0.8908 - val_loss: 0.7337 - val_accuracy: 0.6364 - 1s/epoch - 25ms/step
# Epoch 37/120
# 43/43 - 1s - loss: 0.2783 - accuracy: 0.8544 - val_loss: 0.6394 - val_accuracy: 0.6364 - 1s/epoch - 25ms/step
# Epoch 38/120
# 43/43 - 1s - loss: 0.2560 - accuracy: 0.8806 - val_loss: 0.6931 - val_accuracy: 0.6364 - 1s/epoch - 25ms/step
# Epoch 39/120
# 43/43 - 1s - loss: 0.2516 - accuracy: 0.8836 - val_loss: 0.7453 - val_accuracy: 0.6364 - 1s/epoch - 25ms/step
# Epoch 40/120
# 43/43 - 1s - loss: 0.2326 - accuracy: 0.8952 - val_loss: 0.8388 - val_accuracy: 0.6364 - 1s/epoch - 25ms/step
# Epoch 41/120
# 43/43 - 1s - loss: 0.2253 - accuracy: 0.8981 - val_loss: 0.6809 - val_accuracy: 0.6494 - 1s/epoch - 25ms/step
# Epoch 42/120
# 43/43 - 1s - loss: 0.2227 - accuracy: 0.8967 - val_loss: 0.6877 - val_accuracy: 0.6753 - 1s/epoch - 25ms/step
# Epoch 43/120
# 43/43 - 1s - loss: 0.2115 - accuracy: 0.9025 - val_loss: 0.6606 - val_accuracy: 0.7013 - 1s/epoch - 25ms/step
# Epoch 44/120
# 43/43 - 1s - loss: 0.2226 - accuracy: 0.9098 - val_loss: 0.6926 - val_accuracy: 0.6883 - 1s/epoch - 25ms/step
# Epoch 45/120
# 43/43 - 1s - loss: 0.2369 - accuracy: 0.8865 - val_loss: 0.5656 - val_accuracy: 0.7013 - 1s/epoch - 25ms/step
# Epoch 46/120
# 43/43 - 1s - loss: 0.2383 - accuracy: 0.8894 - val_loss: 0.6274 - val_accuracy: 0.6494 - 1s/epoch - 25ms/step
# Epoch 47/120
# 43/43 - 1s - loss: 0.1770 - accuracy: 0.9258 - val_loss: 0.5971 - val_accuracy: 0.7013 - 1s/epoch - 25ms/step
# Epoch 48/120
# 43/43 - 1s - loss: 0.1921 - accuracy: 0.9229 - val_loss: 0.6007 - val_accuracy: 0.6753 - 1s/epoch - 25ms/step
# Epoch 49/120
# 43/43 - 1s - loss: 0.1902 - accuracy: 0.9214 - val_loss: 0.5578 - val_accuracy: 0.6753 - 1s/epoch - 25ms/step
# Epoch 50/120
# 43/43 - 1s - loss: 0.1850 - accuracy: 0.9330 - val_loss: 0.5493 - val_accuracy: 0.6883 - 1s/epoch - 25ms/step
# Epoch 51/120
# 43/43 - 1s - loss: 0.1700 - accuracy: 0.9272 - val_loss: 0.6721 - val_accuracy: 0.6753 - 1s/epoch - 25ms/step
# Epoch 52/120
# 43/43 - 1s - loss: 0.1822 - accuracy: 0.9083 - val_loss: 0.6317 - val_accuracy: 0.6883 - 1s/epoch - 25ms/step
# Epoch 53/120
# 43/43 - 1s - loss: 0.1844 - accuracy: 0.9112 - val_loss: 0.5530 - val_accuracy: 0.7143 - 1s/epoch - 25ms/step
# Epoch 54/120
# 43/43 - 1s - loss: 0.1610 - accuracy: 0.9316 - val_loss: 0.4935 - val_accuracy: 0.6883 - 1s/epoch - 25ms/step
# Epoch 55/120
# 43/43 - 1s - loss: 0.1408 - accuracy: 0.9476 - val_loss: 0.4647 - val_accuracy: 0.7273 - 1s/epoch - 25ms/step
# Epoch 56/120
# 43/43 - 1s - loss: 0.1507 - accuracy: 0.9258 - val_loss: 0.4722 - val_accuracy: 0.7143 - 1s/epoch - 25ms/step
# Epoch 57/120
# 43/43 - 1s - loss: 0.1607 - accuracy: 0.9287 - val_loss: 0.4286 - val_accuracy: 0.7532 - 1s/epoch - 25ms/step
# Epoch 58/120
# 43/43 - 1s - loss: 0.1462 - accuracy: 0.9272 - val_loss: 0.4553 - val_accuracy: 0.7792 - 1s/epoch - 26ms/step
# Epoch 59/120
# 43/43 - 1s - loss: 0.1524 - accuracy: 0.9258 - val_loss: 0.4815 - val_accuracy: 0.7273 - 1s/epoch - 25ms/step
# Epoch 60/120
# 43/43 - 1s - loss: 0.1372 - accuracy: 0.9389 - val_loss: 0.4681 - val_accuracy: 0.7403 - 1s/epoch - 25ms/step
# Epoch 61/120
# 43/43 - 1s - loss: 0.1435 - accuracy: 0.9345 - val_loss: 0.4555 - val_accuracy: 0.7403 - 1s/epoch - 25ms/step
# Epoch 62/120
# 43/43 - 1s - loss: 0.1430 - accuracy: 0.9316 - val_loss: 0.4706 - val_accuracy: 0.7273 - 1s/epoch - 25ms/step
# Epoch 63/120
# 43/43 - 1s - loss: 0.1391 - accuracy: 0.9229 - val_loss: 0.4462 - val_accuracy: 0.7532 - 1s/epoch - 25ms/step
# Epoch 64/120
# 43/43 - 1s - loss: 0.1491 - accuracy: 0.9243 - val_loss: 0.4791 - val_accuracy: 0.7273 - 1s/epoch - 26ms/step
# Epoch 65/120
# 43/43 - 1s - loss: 0.1211 - accuracy: 0.9403 - val_loss: 0.5107 - val_accuracy: 0.7403 - 1s/epoch - 26ms/step
# Epoch 66/120
# 43/43 - 1s - loss: 0.1019 - accuracy: 0.9563 - val_loss: 0.4744 - val_accuracy: 0.7532 - 1s/epoch - 25ms/step
# Epoch 67/120
# 43/43 - 1s - loss: 0.1109 - accuracy: 0.9476 - val_loss: 0.5000 - val_accuracy: 0.8052 - 1s/epoch - 25ms/step
# Epoch 68/120
# 43/43 - 1s - loss: 0.1106 - accuracy: 0.9432 - val_loss: 0.4705 - val_accuracy: 0.7792 - 1s/epoch - 25ms/step
# Epoch 69/120
# 43/43 - 1s - loss: 0.1067 - accuracy: 0.9549 - val_loss: 0.4615 - val_accuracy: 0.7922 - 1s/epoch - 25ms/step
# Epoch 70/120
# 43/43 - 1s - loss: 0.1159 - accuracy: 0.9418 - val_loss: 0.4952 - val_accuracy: 0.7792 - 1s/epoch - 25ms/step
# Epoch 71/120
# 43/43 - 1s - loss: 0.1085 - accuracy: 0.9491 - val_loss: 0.4252 - val_accuracy: 0.8312 - 1s/epoch - 25ms/step
# Epoch
- val_accuracy: 0.8442 - 1s/epoch - 26ms/step
# Epoch 98/120
# 43/43 - 1s - loss: 0.0591 - accuracy: 0.9753 - val_loss: 0.3697 - val_accuracy: 0.8312 - 1s/epoch - 25ms/step
# Epoch 99/120
# 43/43 - 1s - loss: 0.0626 - accuracy: 0.9709 - val_loss: 0.3818 - val_accuracy: 0.8442 - 1s/epoch - 25ms/step
# Epoch 100/120
# 43/43 - 1s - loss: 0.0407 - accuracy: 0.9840 - val_loss: 0.4486 - val_accuracy: 0.8442 - 1s/epoch - 25ms/step
# Epoch 101/120
# 43/43 - 1s - loss: 0.0607 - accuracy: 0.9694 - val_loss: 0.3673 - val_accuracy: 0.8831 - 1s/epoch - 25ms/step
# Epoch 102/120
# 43/43 - 1s - loss: 0.0562 - accuracy: 0.9825 - val_loss: 0.3842 - val_accuracy: 0.8442 - 1s/epoch - 25ms/step
# Epoch 103/120
# 43/43 - 1s - loss: 0.0633 - accuracy: 0.9694 - val_loss: 0.3797 - val_accuracy: 0.8571 - 1s/epoch - 25ms/step
# Epoch 104/120
# 43/43 - 1s - loss: 0.0534 - accuracy: 0.9796 - val_loss: 0.3836 - val_accuracy: 0.8442 - 1s/epoch - 25ms/step
# Epoch 105/120
# 43/43 - 1s - loss: 0.0516 - accuracy: 0.9840 - val_loss: 0.3883 - val_accuracy: 0.8442 - 1s/epoch - 25ms/step
# Epoch 106/120
# 43/43 - 1s - loss: 0.0689 - accuracy: 0.9709 - val_loss: 0.3764 - val_accuracy: 0.8831 - 1s/epoch - 25ms/step
# Epoch 107/120
# 43/43 - 1s - loss: 0.0635 - accuracy: 0.9753 - val_loss: 0.4267 - val_accuracy: 0.8571 - 1s/epoch - 25ms/step
# Epoch 108/120
# 43/43 - 1s - loss: 0.0620 - accuracy: 0.9753 - val_loss: 0.3913 - val_accuracy: 0.8571 - 1s/epoch - 25ms/step
# Epoch 109/120
# 43/43 - 1s - loss: 0.0473 - accuracy: 0.9796 - val_loss: 0.3953 - val_accuracy: 0.8442 - 1s/epoch - 25ms/step
# Epoch 110/120
# 43/43 - 1s - loss: 0.0474 - accuracy: 0.9753 - val_loss: 0.3928 - val_accuracy: 0.8312 - 1s/epoch - 25ms/step
# Epoch 111/120
# 43/43 - 1s - loss: 0.0661 - accuracy: 0.9607 - val_loss: 0.3941 - val_accuracy: 0.8701 - 1s/epoch - 26ms/step
# Epoch 112/120
# 43/43 - 1s - loss: 0.0551 - accuracy: 0.9767 - val_loss: 0.4080 - val_accuracy: 0.8442 - 1s/epoch - 26ms/step
# Epoch 113/120
# 43/43 - 1s - loss: 0.0515 - accuracy: 0.9811 - val_loss: 0.4509 - val_accuracy: 0.8571 - 1s/epoch - 25ms/step
# Epoch 114/120
# 43/43 - 1s - loss: 0.0539 - accuracy: 0.9811 - val_loss: 0.4488 - val_accuracy: 0.8571 - 1s/epoch - 26ms/step
# Epoch 115/120
# 43/43 - 1s - loss: 0.0412 - accuracy: 0.9782 - val_loss: 0.4158 - val_accuracy: 0.8961 - 1s/epoch - 26ms/step
# Epoch 116/120
# 43/43 - 1s - loss: 0.0524 - accuracy: 0.9782 - val_loss: 0.4166 - val_accuracy: 0.8571 - 1s/epoch - 25ms/step
# Epoch 117/120
# 43/43 - 1s - loss: 0.0430 - accuracy: 0.9796 - val_loss: 0.4013 - val_accuracy: 0.8571 - 1s/epoch - 25ms/step
# Epoch 118/120
# 43/43 - 1s - loss: 0.0373 - accuracy: 0.9884 - val_loss: 0.4050 - val_accuracy: 0.8701 - 1s/epoch - 25ms/step
# Epoch 119/120
# 43/43 - 1s - loss: 0.0488 - accuracy: 0.9825 - val_loss: 0.4218 - val_accuracy: 0.8571 - 1s/epoch - 25ms/step
# Epoch 120/120
# 43/43 - 1s - loss: 0.0451 - accuracy: 0.9854 - val_loss: 0.5353 - val_accuracy: 0.8571 - 1s/epoch - 25ms/step

# %%
network_analysis(CNN_model,CNN_fit,X_test,y_test)
# Out:
# 3/3 [==============================] - 1s 110ms/step - loss: 0.6313 - accuracy: 0.8000
# 3/3 [==============================] - 0s 9ms/step
# Test accuracy:80.0%
# Model fit and testing time:135.67s
